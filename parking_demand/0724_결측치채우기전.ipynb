# %%
import pandas as pd
import seaborn as sns
import warnings 
from matplotlib import rc, rcParams
import matplotlib.pyplot as plt

warnings.filterwarnings(action='ignore')
rc('font',family='AppleGothic')
rcParams['axes.unicode_minus']= False

# %%
path = './data/'

train = pd.read_csv(path+'2_train.csv')
test = pd.read_csv(path+'2_test.csv')

train.shape, test.shape
# Out:
# ((2952, 62), (1008, 61))

# %%
train.iloc[:,[1,5,6,7,9,10,11,12,13,-1]].head(1)
# Out:
#    총세대수   전용면적  전용면적별세대수   공가수       임대보증금       임대료  지하철  버스정류장  단지내주차면수  \
# 0   900  39.72       134  38.0  15667000.0  103680.0  0.0    3.0   1425.0
#
#     등록차량수
# 0  1015.0

# %%
# tmp_train = train[['임대보증금','임대료','등록차량수']]
tmp_train = train.iloc[:,[1,5,6,7,9,10,11,12,13,-1]]

plt.figure(figsize=(8,6))
sns.heatmap(tmp_train.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
path = './data_임대보증금임대료/'

train = pd.read_csv(path+'train_new.csv')
test = pd.read_csv(path+'test_new.csv')

train.shape, test.shape
# Out:
# ((3184, 68), (776, 68))
